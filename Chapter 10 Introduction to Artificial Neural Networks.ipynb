# %% [markdown]
# # Introduction to Artificial Neural Networks
#
# ## From Biological to Artificial Neurons
#
# * ANNs were first introduced back in 1943 by the neurophysiologist Warren McCulloch and the mathematician Walter Pitts.
#
# * We are now witnessing a wave of interest in ANNs.
#
# * There is now a huge quantity of data available to train neural networks
#
# * The tremendous increase in computing power since the 1990s now makes it posible to train large neural networks in a resonable amount of time.
#
# * The training algorithms have been improved.
#
# * Some theoretical limitations of ANNs have turned out to be benign in practice.
#
# * ANNs seem to have entered a virtuous circle of funding and progress.
#
# ### Biological Neurons
#
# * Biological neurons receive short electrical impulses called signals from other neurons via synapses.
#
# ### Logical Computations with Neurons
#
# * The artificial neuron simply activates its output when more than a certain number of its inputs are active.
#
# ### The Perceptron
#
# * The perceptron is one of the simplest ANN architectures, invented in 1957 by Frank Rosenblatt.
#
# * Liear threshold unit(LTU): the inputs and output are now numbers(instead of binary on/off values) and each input connection is associated with weight. The LTU computes a weighted sum of its inputs, then applies step function to that sum and outputs the result.
#
# * A single LTU can be used for simple linear binary classification.
#
# * A Perceptron trained in this way: the connection weight between two neurons is increased whenever they have the same output.

# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.linear_model import Perceptron

iris = load_iris()
X = iris.data[:, (2, 3)]
y = (iris.target==0).astype(np.int)

per_clf = Perceptron(random_state=42)
per_clf.fit(X, y )

y_pred = per_clf.predict([[2, 0.5]])

# %%
y_pred
# Out:
# array([1])

# %% [markdown]
# ### Multi-Layer Perceptron and Backpropagation
#
# * An MLP is composed of one input layer, one or more layers of LTUs, called hiiden layers ,and one final layer of LTUs called the output layer.
#
# * Every layer except the output layer includes a bias neuron and is fuly connected to the next layer.
#
# * For each training instance the backpropagation algorithm first makes a predcition(forward pass), measures the error, then goes through each layer in reverse to measure the error contribution from each connection, and finally slightly tweaks the connection weights to reduce the error(Gradient Descent step).
#
# * In order for this algorithm to work properly, the authors made a key change to MLP's architecture: they replaced the step function with the logistic function.
#
# * Activation functions: Step function, Sigmoid function, Tanh function, Relu function.
#
# ## Training an MLP with TensorFlow's High-Level API

# %%
# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

from tensorflow.examples.tutorials.mnist import input_data

mnist = input_data.read_data_sets("/tmp/data")
# Out:
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %%
X_train = mnist.train.images
X_test = mnist.test.images
y_train = mnist.train.labels.astype("int")
y_test = mnist.test.labels.astype("int")

# %%
import tensorflow as tf

config = tf.contrib.learn.RunConfig(tf_random_seed=42)

feature_columns = tf.contrib.learn.infer_real_valued_columns_from_input(X_train)
dnn_clf = tf.contrib.learn.DNNClassifier(hidden_units=[300, 100], n_classes=10, 
                                        feature_columns=feature_columns)

dnn_clf.fit(x=X_train, y=y_train, batch_size=50, steps=40000)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/__/2zbjvd9s6w54xb911mgsqj6w0000gn/T/tmps9a3c8vc
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x125c26b38>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/var/folders/__/2zbjvd9s6w54xb911mgsqj6w0000gn/T/tmps9a3c8vc'}
# WARNING:tensorflow:From <ipython-input-7-f228096ab37e>:9: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-7-f228096ab37e>:9: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-7-f228096ab37e>:9: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with batch_size is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From //anaconda/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/__/2zbjvd9s6w54xb911mgsqj6w0000gn/T/tmps9a3c8vc/model.ckpt.
# INFO:tensorflow:loss = 2.42038, step = 1
# INFO:tensorflow:global_step/sec: 151.138
# INFO:tensorflow:loss = 0.363946, step = 101 (0.669 sec)
# INFO:tensorflow:global_step/sec: 149.261
# INFO:tensorflow:loss = 0.270842, step = 201 (0.664 sec)
# INFO:tensorflow:global_step/sec: 189.273
# INFO:tensorflow:loss = 0.376795, step = 301 (0.529 sec)
# INFO:tensorflow:global_step/sec: 147.727
# INFO:tensorflow:loss = 0.203486, step = 401 (0.676 sec)
# INFO:tensorflow:global_step/sec: 183.653
# INFO:tensorflow:loss = 0.254988, step = 501 (0.545 sec)
# INFO:tensorflow:global_step/sec: 165.893
# INFO:tensorflow:loss = 0.0657265, step = 601 (0.606 sec)
# INFO:tensorflow:global_step/sec: 149.214
# INFO:tensorflow:loss = 0.137552, step = 701 (0.668 sec)
# INFO:tensorflow:global_step/sec: 180.592
# INFO:tensorflow:loss = 0.229865, step = 801 (0.554 sec)
# INFO:tensorflow:global_step/sec: 177.225
# INFO:tensorflow:loss = 0.100344, step = 901 (0.564 sec)
# INFO:tensorflow:global_step/sec: 153.058
# INFO:tensorflow:loss = 0.182837, step = 1001 (0.653 sec)
# INFO:tensorflow:global_step/sec: 199.352
# INFO:tensorflow:loss = 0.188281, step = 1101 (0.502 sec)
# INFO:tensorflow:global_step/sec: 150.026
# INFO:tensorflow:loss = 0.16715, step = 1201 (0.667 sec)
# INFO:tensorflow:global_step/sec: 178.129
# INFO:tensorflow:loss = 0.139288, step = 1301 (0.561 sec)
# INFO:tensorflow:global_step/sec: 176.346
# INFO:tensorflow:loss = 0.0908149, step = 1401 (0.567 sec)
# INFO:tensorflow:global_step/sec: 155.668
# INFO:tensorflow:loss = 0.111148, step = 1501 (0.648 sec)
# INFO:tensorflow:global_step/sec: 152.963
# INFO:tensorflow:loss = 0.114836, step = 1601 (0.649 sec)
# INFO:tensorflow:global_step/sec: 195.207
# INFO:tensorflow:loss = 0.0387558, step = 1701 (0.512 sec)
# INFO:tensorflow:global_step/sec: 189.572
# INFO:tensorflow:loss = 0.156815, step = 1801 (0.528 sec)
# INFO:tensorflow:global_step/sec: 193.13
# INFO:tensorflow:loss = 0.0694965, step = 1901 (0.517 sec)
# INFO:tensorflow:global_step/sec: 202.687
# INFO:tensorflow:loss = 0.082928, step = 2001 (0.493 sec)
# INFO:tensorflow:global_step/sec: 203.216
# INFO:tensorflow:loss = 0.0265572, step = 2101 (0.493 sec)
# INFO:tensorflow:global_step/sec: 199.128
# INFO:tensorflow:loss = 0.0373045, step = 2201 (0.502 sec)
# INFO:tensorflow:global_step/sec: 201.789
# INFO:tensorflow:loss = 0.0533127, step = 2301 (0.495 sec)
# INFO:tensorflow:global_step/sec: 202.932
# INFO:tensorflow:loss = 0.0558582, step = 2401 (0.493 sec)
# INFO:tensorflow:global_step/sec: 195.323
# INFO:tensorflow:loss = 0.0817615, step = 2501 (0.513 sec)
# INFO:tensorflow:global_step/sec: 180.819
# INFO:tensorflow:loss = 0.0523086, step = 2601 (0.553 sec)
# INFO:tensorflow:global_step/sec: 188.285
# INFO:tensorflow:loss = 0.0138126, step = 2701 (0.531 sec)
# INFO:tensorflow:global_step/sec: 189.637
# INFO:tensorflow:loss = 0.0379685, step = 2801 (0.527 sec)
# INFO:tensorflow:global_step/sec: 190.201
# INFO:tensorflow:loss = 0.115884, step = 2901 (0.527 sec)
# INFO:tensorflow:global_step/sec: 176.296
# INFO:tensorflow:loss = 0.0225204, step = 3001 (0.566 sec)
# INFO:tensorflow:global_step/sec: 169.449
# INFO:tensorflow:loss = 0.0266934, step = 3101 (0.591 sec)
# INFO:tensorflow:global_step/sec: 169.94
# INFO:tensorflow:loss = 0.0186511, step = 3201 (0.588 sec)
# INFO:tensorflow:global_step/sec: 178.641
# INFO:tensorflow:loss = 0.0247979, step = 3301 (0.560 sec)
# INFO:tensorflow:global_step/sec: 183.548
# INFO:tensorflow:loss = 0.149891, step = 3401 (0.547 sec)
# INFO:tensorflow:global_step/sec: 188.294
# INFO:tensorflow:loss = 0.106811, step = 3501 (0.529 sec)
# INFO:tensorflow:global_step/sec: 191.049
# INFO:tensorflow:loss = 0.184573, step = 3601 (0.523 sec)
# INFO:tensorflow:global_step/sec: 164.986
# INFO:tensorflow:loss = 0.0460723, step = 3701 (0.609 sec)
# INFO:tensorflow:global_step/sec: 155.975
# INFO:tensorflow:loss = 0.0062155, step = 3801 (0.642 sec)
# INFO:tensorflow:global_step/sec: 130.378
# INFO:tensorflow:loss = 0.0862197, step = 3901 (0.764 sec)
# INFO:tensorflow:global_step/sec: 167.773
# INFO:tensorflow:loss = 0.136804, step = 4001 (0.600 sec)
# INFO:tensorflow:global_step/sec: 189.035
# INFO:tensorflow:loss = 0.0261628, step = 4101 (0.524 sec)
# INFO:tensorflow:global_step/sec: 205.858
# INFO:tensorflow:loss = 0.0659468, step = 4201 (0.486 sec)
# INFO:tensorflow:global_step/sec: 197.679
# INFO:tensorflow:loss = 0.147729, step = 4301 (0.506 sec)
# INFO:tensorflow:global_step/sec: 202
# INFO:tensorflow:loss = 0.135936, step = 4401 (0.495 sec)
# INFO:tensorflow:global_step/sec: 139.322
# INFO:tensorflow:loss = 0.0424387, step = 4501 (0.720 sec)
# INFO:tensorflow:global_step/sec: 139.507
# INFO:tensorflow:loss = 0.0293266, step = 4601 (0.720 sec)
# INFO:tensorflow:global_step/sec: 133.208
# INFO:tensorflow:loss = 0.0113152, step = 4701 (0.750 sec)
# INFO:tensorflow:global_step/sec: 154.758
# INFO:tensorflow:loss = 0.0346916, step = 4801 (0.646 sec)
# INFO:tensorflow:global_step/sec: 130.083
# INFO:tensorflow:loss = 0.0835875, step = 4901 (0.769 sec)
# INFO:tensorflow:global_step/sec: 153.616
# INFO:tensorflow:loss = 0.0562304, step = 5001 (0.650 sec)
# INFO:tensorflow:global_step/sec: 145.263
# INFO:tensorflow:loss = 0.0169518, step = 5101 (0.692 sec)
# INFO:tensorflow:global_step/sec: 133.927
# INFO:tensorflow:loss = 0.0312494, step = 5201 (0.746 sec)
# INFO:tensorflow:global_step/sec: 142.45
# INFO:tensorflow:loss = 0.0192431, step = 5301 (0.699 sec)
# INFO:tensorflow:global_step/sec: 150.491
# INFO:tensorflow:loss = 0.0254593, step = 5401 (0.663 sec)
# INFO:tensorflow:global_step/sec: 146.112
# INFO:tensorflow:loss = 0.0328873, step = 5501 (0.689 sec)
# INFO:tensorflow:global_step/sec: 186.487
# INFO:tensorflow:loss = 0.0602061, step = 5601 (0.531 sec)
# INFO:tensorflow:global_step/sec: 188.152
# INFO:tensorflow:loss = 0.0102319, step = 5701 (0.531 sec)
# INFO:tensorflow:global_step/sec: 186.509
# INFO:tensorflow:loss = 0.00845423, step = 5801 (0.537 sec)
# INFO:tensorflow:global_step/sec: 188.301
# INFO:tensorflow:loss = 0.10053, step = 5901 (0.530 sec)
# INFO:tensorflow:global_step/sec: 150.755
# INFO:tensorflow:loss = 0.0913576, step = 6001 (0.664 sec)
# INFO:tensorflow:global_step/sec: 157.775
# INFO:tensorflow:loss = 0.0133071, step = 6101 (0.637 sec)
# INFO:tensorflow:global_step/sec: 187.762
# INFO:tensorflow:loss = 0.0162009, step = 6201 (0.529 sec)
# INFO:tensorflow:global_step/sec: 174.596
# INFO:tensorflow:loss = 0.0622732, step = 6301 (0.573 sec)
# INFO:tensorflow:global_step/sec: 188.373
# INFO:tensorflow:loss = 0.0487826, step = 6401 (0.531 sec)
# INFO:tensorflow:global_step/sec: 198.693
# INFO:tensorflow:loss = 0.0106242, step = 6501 (0.504 sec)
# INFO:tensorflow:global_step/sec: 187.328
# INFO:tensorflow:loss = 0.0126047, step = 6601 (0.533 sec)
# INFO:tensorflow:global_step/sec: 190.676
# INFO:tensorflow:loss = 0.0192103, step = 6701 (0.524 sec)
# INFO:tensorflow:global_step/sec: 184.789
# INFO:tensorflow:loss = 0.00772792, step = 6801 (0.541 sec)
# INFO:tensorflow:global_step/sec: 170.752
# INFO:tensorflow:loss = 0.0211235, step = 6901 (0.590 sec)
# INFO:tensorflow:global_step/sec: 131.773
# INFO:tensorflow:loss = 0.0250562, step = 7001 (0.754 sec)
# INFO:tensorflow:global_step/sec: 158.63
# INFO:tensorflow:loss = 0.00621712, step = 7101 (0.631 sec)
# INFO:tensorflow:global_step/sec: 159.071
# INFO:tensorflow:loss = 0.0363575, step = 7201 (0.628 sec)
# INFO:tensorflow:global_step/sec: 161.222
# INFO:tensorflow:loss = 0.00687805, step = 7301 (0.621 sec)
# INFO:tensorflow:global_step/sec: 154.16
# INFO:tensorflow:loss = 0.0210036, step = 7401 (0.648 sec)
# INFO:tensorflow:global_step/sec: 162.019
# INFO:tensorflow:loss = 0.00164177, step = 7501 (0.623 sec)
# INFO:tensorflow:global_step/sec: 137.473
# INFO:tensorflow:loss = 0.0135573, step = 7601 (0.722 sec)
# INFO:tensorflow:global_step/sec: 171.542
# INFO:tensorflow:loss = 0.0140058, step = 7701 (0.586 sec)
# INFO:tensorflow:global_step/sec: 163.715
# INFO:tensorflow:loss = 0.004008, step = 7801 (0.607 sec)
# INFO:tensorflow:global_step/sec: 183.159
# INFO:tensorflow:loss = 0.00594047, step = 7901 (0.550 sec)
# INFO:tensorflow:global_step/sec: 165.302
# INFO:tensorflow:loss = 0.00218173, step = 8001 (0.602 sec)
# INFO:tensorflow:global_step/sec: 171.468
# INFO:tensorflow:loss = 0.0148689, step = 8101 (0.591 sec)
# INFO:tensorflow:global_step/sec: 137.415
# INFO:tensorflow:loss = 0.0191606, step = 8201 (0.721 sec)
# INFO:tensorflow:global_step/sec: 170.363
# INFO:tensorflow:loss = 0.0493824, step = 8301 (0.589 sec)
# INFO:tensorflow:global_step/sec: 172.069
# INFO:tensorflow:loss = 0.00638928, step = 8401 (0.577 sec)
# INFO:tensorflow:global_step/sec: 172.842
# INFO:tensorflow:loss = 0.00533452, step = 8501 (0.584 sec)
# INFO:tensorflow:global_step/sec: 136.043
# INFO:tensorflow:loss = 0.00379279, step = 8601 (0.732 sec)
# INFO:tensorflow:global_step/sec: 143.523
# INFO:tensorflow:loss = 0.0022567, step = 8701 (0.700 sec)
# INFO:tensorflow:global_step/sec: 143.01
# INFO:tensorflow:loss = 0.0150413, step = 8801 (0.695 sec)
# INFO:tensorflow:global_step/sec: 142.357
# INFO:tensorflow:loss = 0.001587, step = 8901 (0.704 sec)
# INFO:tensorflow:global_step/sec: 171.609
# INFO:tensorflow:loss = 0.01009, step = 9001 (0.581 sec)
# INFO:tensorflow:global_step/sec: 179.775
# INFO:tensorflow:loss = 0.00570861, step = 9101 (0.556 sec)
# INFO:tensorflow:global_step/sec: 191.07
# INFO:tensorflow:loss = 0.00764823, step = 9201 (0.523 sec)
# INFO:tensorflow:global_step/sec: 201.118
# INFO:tensorflow:loss = 0.00803377, step = 9301 (0.497 sec)
# INFO:tensorflow:global_step/sec: 192.217
# INFO:tensorflow:loss = 0.0416087, step = 9401 (0.520 sec)
# INFO:tensorflow:global_step/sec: 201.371
# INFO:tensorflow:loss = 0.00639187, step = 9501 (0.497 sec)
# INFO:tensorflow:global_step/sec: 194.003
# INFO:tensorflow:loss = 0.0180174, step = 9601 (0.516 sec)
# INFO:tensorflow:global_step/sec: 198.84
# INFO:tensorflow:loss = 0.00636095, step = 9701 (0.504 sec)
# INFO:tensorflow:global_step/sec: 197.971
# INFO:tensorflow:loss = 0.012627, step = 9801 (0.505 sec)
# INFO:tensorflow:global_step/sec: 202.432
# INFO:tensorflow:loss = 0.0202727, step = 9901 (0.494 sec)
# INFO:tensorflow:global_step/sec: 195.444
# INFO:tensorflow:loss = 0.00883505, step = 10001 (0.512 sec)
# INFO:tensorflow:global_step/sec: 203.995
# INFO:tensorflow:loss = 0.00663346, step = 10101 (0.491 sec)
# INFO:tensorflow:global_step/sec: 196.786
# INFO:tensorflow:loss = 0.00799688, step = 10201 (0.509 sec)
# INFO:tensorflow:global_step/sec: 203.812
# INFO:tensorflow:loss = 0.0047126, step = 10301 (0.490 sec)
# INFO:tensorflow:global_step/sec: 193.356
# INFO:tensorflow:loss = 0.00864736, step = 10401 (0.517 sec)
# INFO:tensorflow:global_step/sec: 203.998
# INFO:tensorflow:loss = 0.00165705, step = 10501 (0.490 sec)
# INFO:tensorflow:global_step/sec: 195.824
# INFO:tensorflow:loss = 0.0106043, step = 10601 (0.511 sec)
# INFO:tensorflow:global_step/sec: 169.659
# INFO:tensorflow:loss = 0.0299777, step = 10701 (0.596 sec)
# INFO:tensorflow:global_step/sec: 167.514
# INFO:tensorflow:loss = 0.00516427, step = 10801 (0.590 sec)
# INFO:tensorflow:global_step/sec: 184.38
# INFO:tensorflow:loss = 0.00283155, step = 10901 (0.543 sec)
# INFO:tensorflow:global_step/sec: 195.547
# INFO:tensorflow:loss = 0.017121, step = 11001 (0.511 sec)
# INFO:tensorflow:global_step/sec: 190.142
# INFO:tensorflow:loss = 0.0054677, step = 11101 (0.527 sec)
# INFO:tensorflow:global_step/sec: 196.299
# INFO:tensorflow:loss = 0.00131389, step = 11201 (0.509 sec)
# INFO:tensorflow:global_step/sec: 177.149
# INFO:tensorflow:loss = 0.00513774, step = 11301 (0.565 sec)
# INFO:tensorflow:global_step/sec: 151.36
# INFO:tensorflow:loss = 0.00685794, step = 11401 (0.662 sec)
# INFO:tensorflow:global_step/sec: 136.086
# INFO:tensorflow:loss = 0.0182866, step = 11501 (0.737 sec)
# INFO:tensorflow:global_step/sec: 142.19
# INFO:tensorflow:loss = 0.00153485, step = 11601 (0.699 sec)
# INFO:tensorflow:global_step/sec: 164.352
# INFO:tensorflow:loss = 0.00412809, step = 11701 (0.609 sec)
# INFO:tensorflow:global_step/sec: 201.267
# INFO:tensorflow:loss = 0.000357594, step = 11801 (0.497 sec)
# INFO:tensorflow:global_step/sec: 186.567
# INFO:tensorflow:loss = 0.00218628, step = 11901 (0.535 sec)
# INFO:tensorflow:global_step/sec: 196.153
# INFO:tensorflow:loss = 0.000320015, step = 12001 (0.510 sec)
# INFO:tensorflow:global_step/sec: 191.681
# INFO:tensorflow:loss = 0.00156114, step = 12101 (0.523 sec)
# INFO:tensorflow:global_step/sec: 184.394
# INFO:tensorflow:loss = 0.00425549, step = 12201 (0.542 sec)
# INFO:tensorflow:global_step/sec: 192.975
# INFO:tensorflow:loss = 0.00642109, step = 12301 (0.518 sec)
# INFO:tensorflow:global_step/sec: 203.837
# INFO:tensorflow:loss = 0.000360641, step = 12401 (0.490 sec)
# INFO:tensorflow:global_step/sec: 200.621
# INFO:tensorflow:loss = 0.00249476, step = 12501 (0.501 sec)
# INFO:tensorflow:global_step/sec: 191.079
# INFO:tensorflow:loss = 0.00186316, step = 12601 (0.521 sec)
# INFO:tensorflow:global_step/sec: 201.868
# INFO:tensorflow:loss = 0.00465397, step = 12701 (0.496 sec)
# INFO:tensorflow:global_step/sec: 202.694
# INFO:tensorflow:loss = 0.00796022, step = 12801 (0.493 sec)
# INFO:tensorflow:global_step/sec: 199.165
# INFO:tensorflow:loss = 0.00409004, step = 12901 (0.502 sec)
# INFO:tensorflow:global_step/sec: 193.848
# INFO:tensorflow:loss = 0.00739801, step = 13001 (0.516 sec)
# INFO:tensorflow:global_step/sec: 195.207
# INFO:tensorflow:loss = 0.00756624, step = 13101 (0.512 sec)
# INFO:tensorflow:global_step/sec: 161.958
# INFO:tensorflow:loss = 0.00526367, step = 13201 (0.623 sec)
# INFO:tensorflow:global_step/sec: 144.546
# INFO:tensorflow:loss = 0.0040021, step = 13301 (0.687 sec)
# INFO:tensorflow:global_step/sec: 167.836
# INFO:tensorflow:loss = 0.00896635, step = 13401 (0.598 sec)
# INFO:tensorflow:global_step/sec: 179.972
# INFO:tensorflow:loss = 0.00429483, step = 13501 (0.557 sec)
# INFO:tensorflow:global_step/sec: 187.864
# INFO:tensorflow:loss = 0.0041055, step = 13601 (0.529 sec)
# INFO:tensorflow:global_step/sec: 167.012
# INFO:tensorflow:loss = 0.0023072, step = 13701 (0.601 sec)
# INFO:tensorflow:global_step/sec: 163.991
# INFO:tensorflow:loss = 0.0054363, step = 13801 (0.609 sec)
# INFO:tensorflow:global_step/sec: 167.085
# INFO:tensorflow:loss = 0.0019986, step = 13901 (0.599 sec)
# INFO:tensorflow:global_step/sec: 168.769
# INFO:tensorflow:loss = 0.00167922, step = 14001 (0.590 sec)
# INFO:tensorflow:global_step/sec: 157.752
# INFO:tensorflow:loss = 0.00725094, step = 14101 (0.636 sec)
# INFO:tensorflow:global_step/sec: 166.82
# INFO:tensorflow:loss = 0.00601577, step = 14201 (0.597 sec)
# INFO:tensorflow:global_step/sec: 134.689
# INFO:tensorflow:loss = 0.00179633, step = 14301 (0.748 sec)
# INFO:tensorflow:global_step/sec: 155.992
# INFO:tensorflow:loss = 0.000499543, step = 14401 (0.637 sec)
# INFO:tensorflow:global_step/sec: 135.064
# INFO:tensorflow:loss = 0.000580099, step = 14501 (0.745 sec)
# INFO:tensorflow:global_step/sec: 140.963
# INFO:tensorflow:loss = 0.00394197, step = 14601 (0.705 sec)
# INFO:tensorflow:global_step/sec: 147.09
# INFO:tensorflow:loss = 0.00160264, step = 14701 (0.682 sec)
# INFO:tensorflow:global_step/sec: 163.987
# INFO:tensorflow:loss = 0.000597561, step = 14801 (0.607 sec)
# INFO:tensorflow:global_step/sec: 161.534
# INFO:tensorflow:loss = 0.00220764, step = 14901 (0.619 sec)
# INFO:tensorflow:global_step/sec: 154.552
# INFO:tensorflow:loss = 0.000770006, step = 15001 (0.646 sec)
# INFO:tensorflow:global_step/sec: 165.815
# INFO:tensorflow:loss = 0.00163876, step = 15101 (0.606 sec)
# INFO:tensorflow:global_step/sec: 173.705
# INFO:tensorflow:loss = 0.00150193, step = 15201 (0.573 sec)
# INFO:tensorflow:global_step/sec: 175.101
# INFO:tensorflow:loss = 0.00176058, step = 15301 (0.572 sec)
# INFO:tensorflow:global_step/sec: 159.66
# INFO:tensorflow:loss = 0.00232872, step = 15401 (0.625 sec)
# INFO:tensorflow:global_step/sec: 142.889
# INFO:tensorflow:loss = 0.00545968, step = 15501 (0.700 sec)
# INFO:tensorflow:global_step/sec: 152.186
# INFO:tensorflow:loss = 0.00367263, step = 15601 (0.661 sec)
# INFO:tensorflow:global_step/sec: 175.53
# INFO:tensorflow:loss = 0.00773927, step = 15701 (0.565 sec)
# INFO:tensorflow:global_step/sec: 173.363
# INFO:tensorflow:loss = 0.00176932, step = 15801 (0.576 sec)
# INFO:tensorflow:global_step/sec: 145.24
# INFO:tensorflow:loss = 0.000554777, step = 15901 (0.688 sec)
# INFO:tensorflow:global_step/sec: 194.319
# INFO:tensorflow:loss = 0.0037233, step = 16001 (0.515 sec)
# INFO:tensorflow:global_step/sec: 192.569
# INFO:tensorflow:loss = 0.00381279, step = 16101 (0.521 sec)
# INFO:tensorflow:global_step/sec: 178.265
# INFO:tensorflow:loss = 0.000172207, step = 16201 (0.559 sec)
# INFO:tensorflow:global_step/sec: 157.441
# INFO:tensorflow:loss = 0.00437013, step = 16301 (0.636 sec)
# INFO:tensorflow:global_step/sec: 155.601
# INFO:tensorflow:loss = 0.00126318, step = 16401 (0.646 sec)
# INFO:tensorflow:global_step/sec: 144.106
# INFO:tensorflow:loss = 0.00226311, step = 16501 (0.692 sec)
# INFO:tensorflow:global_step/sec: 142.048
# INFO:tensorflow:loss = 0.00402142, step = 16601 (0.703 sec)
# INFO:tensorflow:global_step/sec: 144.722
# INFO:tensorflow:loss = 0.00289762, step = 16701 (0.694 sec)
# INFO:tensorflow:global_step/sec: 151.263
# INFO:tensorflow:loss = 0.00333933, step = 16801 (0.656 sec)
# INFO:tensorflow:global_step/sec: 152.372
# INFO:tensorflow:loss = 0.00330186, step = 16901 (0.659 sec)
# INFO:tensorflow:global_step/sec: 155.999
# INFO:tensorflow:loss = 0.00411723, step = 17001 (0.642 sec)
# INFO:tensorflow:global_step/sec: 166.614
# INFO:tensorflow:loss = 0.000869307, step = 17101 (0.597 sec)
# INFO:tensorflow:global_step/sec: 140.213
# INFO:tensorflow:loss = 0.00207047, step = 17201 (0.713 sec)
# INFO:tensorflow:global_step/sec: 190.445
# INFO:tensorflow:loss = 0.000983515, step = 17301 (0.527 sec)
# INFO:tensorflow:global_step/sec: 195.617
# INFO:tensorflow:loss = 0.00146109, step = 17401 (0.509 sec)
# INFO:tensorflow:global_step/sec: 181.058
# INFO:tensorflow:loss = 0.0014448, step = 17501 (0.552 sec)
# INFO:tensorflow:global_step/sec: 179.333
# INFO:tensorflow:loss = 0.00148199, step = 17601 (0.559 sec)
# INFO:tensorflow:global_step/sec: 195.502
# INFO:tensorflow:loss = 0.000617073, step = 17701 (0.510 sec)
# INFO:tensorflow:global_step/sec: 186.74
# INFO:tensorflow:loss = 0.00017134, step = 17801 (0.538 sec)
# INFO:tensorflow:global_step/sec: 193.001
# INFO:tensorflow:loss = 0.00348698, step = 17901 (0.518 sec)
# INFO:tensorflow:global_step/sec: 186.575
# INFO:tensorflow:loss = 0.000410941, step = 18001 (0.534 sec)
# INFO:tensorflow:global_step/sec: 188.475
# INFO:tensorflow:loss = 0.000569102, step = 18101 (0.537 sec)
# INFO:tensorflow:global_step/sec: 173.57
# INFO:tensorflow:loss = 0.00365103, step = 18201 (0.573 sec)
# INFO:tensorflow:global_step/sec: 149.765
# INFO:tensorflow:loss = 0.0119022, step = 18301 (0.664 sec)
# INFO:tensorflow:global_step/sec: 173.018
# INFO:tensorflow:loss = 0.00335763, step = 18401 (0.577 sec)
# INFO:tensorflow:global_step/sec: 189.834
# INFO:tensorflow:loss = 0.00356836, step = 18501 (0.527 sec)
# INFO:tensorflow:global_step/sec: 178.445
# INFO:tensorflow:loss = 0.00264518, step = 18601 (0.560 sec)
# INFO:tensorflow:global_step/sec: 184.077
# INFO:tensorflow:loss = 0.0015322, step = 18701 (0.544 sec)
# INFO:tensorflow:global_step/sec: 200.935
# INFO:tensorflow:loss = 0.00192111, step = 18801 (0.497 sec)
# INFO:tensorflow:global_step/sec: 195.06
# INFO:tensorflow:loss = 0.0034361, step = 18901 (0.512 sec)
# INFO:tensorflow:global_step/sec: 194.849
# INFO:tensorflow:loss = 0.00138804, step = 19001 (0.513 sec)
# INFO:tensorflow:global_step/sec: 195.094
# INFO:tensorflow:loss = 0.000267863, step = 19101 (0.513 sec)
# INFO:tensorflow:global_step/sec: 189.553
# INFO:tensorflow:loss = 0.000958363, step = 19201 (0.529 sec)
# INFO:tensorflow:global_step/sec: 186.854
# INFO:tensorflow:loss = 0.00567037, step = 19301 (0.533 sec)
# INFO:tensorflow:global_step/sec: 176.499
# INFO:tensorflow:loss = 0.000398307, step = 19401 (0.567 sec)
# INFO:tensorflow:global_step/sec: 177.505
# INFO:tensorflow:loss = 0.00242609, step = 19501 (0.564 sec)
# INFO:tensorflow:global_step/sec: 192.394
# INFO:tensorflow:loss = 0.000358418, step = 19601 (0.519 sec)
# INFO:tensorflow:global_step/sec: 197.43
# INFO:tensorflow:loss = 0.00011257, step = 19701 (0.507 sec)
# INFO:tensorflow:global_step/sec: 200.773
# INFO:tensorflow:loss = 0.000771291, step = 19801 (0.498 sec)
# INFO:tensorflow:global_step/sec: 177.687
# INFO:tensorflow:loss = 0.000983102, step = 19901 (0.563 sec)
# INFO:tensorflow:global_step/sec: 180.995
# INFO:tensorflow:loss = 0.00276825, step = 20001 (0.553 sec)
# INFO:tensorflow:global_step/sec: 182.155
# INFO:tensorflow:loss = 0.000374202, step = 20101 (0.549 sec)
# INFO:tensorflow:global_step/sec: 172.29
# INFO:tensorflow:loss = 0.00288887, step = 20201 (0.581 sec)
# INFO:tensorflow:global_step/sec: 175.072
# INFO:tensorflow:loss = 0.00164513, step = 20301 (0.573 sec)
# INFO:tensorflow:global_step/sec: 165.655
# INFO:tensorflow:loss = 0.000418235, step = 20401 (0.601 sec)
# INFO:tensorflow:global_step/sec: 181.088
# INFO:tensorflow:loss = 0.00062476, step = 20501 (0.552 sec)
# INFO:tensorflow:global_step/sec: 193.695
# INFO:tensorflow:loss = 0.000981075, step = 20601 (0.516 sec)
# INFO:tensorflow:global_step/sec: 186.638
# INFO:tensorflow:loss = 0.000435015, step = 20701 (0.536 sec)
# INFO:tensorflow:global_step/sec: 186.245
# INFO:tensorflow:loss = 0.00183298, step = 20801 (0.538 sec)
# INFO:tensorflow:global_step/sec: 173.912
# INFO:tensorflow:loss = 0.00117566, step = 20901 (0.575 sec)
# INFO:tensorflow:global_step/sec: 190.689
# INFO:tensorflow:loss = 0.00172484, step = 21001 (0.524 sec)
# INFO:tensorflow:global_step/sec: 183.683
# INFO:tensorflow:loss = 0.000792932, step = 21101 (0.545 sec)
# INFO:tensorflow:global_step/sec: 152.605
# INFO:tensorflow:loss = 0.00441278, step = 21201 (0.655 sec)
# INFO:tensorflow:global_step/sec: 172.102
# INFO:tensorflow:loss = 0.00136379, step = 21301 (0.581 sec)
# INFO:tensorflow:global_step/sec: 190.82
# INFO:tensorflow:loss = 0.00193449, step = 21401 (0.524 sec)
# INFO:tensorflow:global_step/sec: 191.552
# INFO:tensorflow:loss = 0.000320047, step = 21501 (0.522 sec)
# INFO:tensorflow:global_step/sec: 190.336
# INFO:tensorflow:loss = 0.00101775, step = 21601 (0.526 sec)
# INFO:tensorflow:global_step/sec: 176.411
# INFO:tensorflow:loss = 0.000960317, step = 21701 (0.566 sec)
# INFO:tensorflow:global_step/sec: 153.055
# INFO:tensorflow:loss = 0.000685127, step = 21801 (0.655 sec)
# INFO:tensorflow:global_step/sec: 146.995
# INFO:tensorflow:loss = 0.000527547, step = 21901 (0.686 sec)
# INFO:tensorflow:global_step/sec: 153.27
# INFO:tensorflow:loss = 0.00010206, step = 22001 (0.649 sec)
# INFO:tensorflow:global_step/sec: 159.734
# INFO:tensorflow:loss = 0.000308855, step = 22101 (0.622 sec)
# INFO:tensorflow:global_step/sec: 177.086
# INFO:tensorflow:loss = 0.00165137, step = 22201 (0.565 sec)
# INFO:tensorflow:global_step/sec: 199.559
# INFO:tensorflow:loss = 0.00273095, step = 22301 (0.501 sec)
# INFO:tensorflow:global_step/sec: 189.204
# INFO:tensorflow:loss = 0.00170485, step = 22401 (0.528 sec)
# INFO:tensorflow:global_step/sec: 181.309
# INFO:tensorflow:loss = 0.00136832, step = 22501 (0.552 sec)
# INFO:tensorflow:global_step/sec: 194.231
# INFO:tensorflow:loss = 0.00229434, step = 22601 (0.515 sec)
# INFO:tensorflow:global_step/sec: 178.418
# INFO:tensorflow:loss = 0.000700576, step = 22701 (0.561 sec)
# INFO:tensorflow:global_step/sec: 195.19
# INFO:tensorflow:loss = 0.000803309, step = 22801 (0.512 sec)
# INFO:tensorflow:global_step/sec: 184.874
# INFO:tensorflow:loss = 0.00262073, step = 22901 (0.541 sec)
# INFO:tensorflow:global_step/sec: 177.691
# INFO:tensorflow:loss = 0.000537982, step = 23001 (0.565 sec)
# INFO:tensorflow:global_step/sec: 168.423
# INFO:tensorflow:loss = 0.00558598, step = 23101 (0.591 sec)
# INFO:tensorflow:global_step/sec: 186.574
# INFO:tensorflow:loss = 0.00218796, step = 23201 (0.537 sec)
# INFO:tensorflow:global_step/sec: 177.996
# INFO:tensorflow:loss = 0.00241716, step = 23301 (0.561 sec)
# INFO:tensorflow:global_step/sec: 195.002
# INFO:tensorflow:loss = 0.000742213, step = 23401 (0.512 sec)
# INFO:tensorflow:global_step/sec: 200.167
# INFO:tensorflow:loss = 0.000647746, step = 23501 (0.499 sec)
# INFO:tensorflow:global_step/sec: 188.55
# INFO:tensorflow:loss = 0.000531861, step = 23601 (0.530 sec)
# INFO:tensorflow:global_step/sec: 164.103
# INFO:tensorflow:loss = 0.000190302, step = 23701 (0.609 sec)
# INFO:tensorflow:global_step/sec: 147.181
# INFO:tensorflow:loss = 0.001418, step = 23801 (0.682 sec)
# INFO:tensorflow:global_step/sec: 142.961
# INFO:tensorflow:loss = 0.0016343, step = 23901 (0.703 sec)
# INFO:tensorflow:global_step/sec: 179.822
# INFO:tensorflow:loss = 0.00116793, step = 24001 (0.552 sec)
# INFO:tensorflow:global_step/sec: 166.74
# INFO:tensorflow:loss = 0.000367665, step = 24101 (0.604 sec)
# INFO:tensorflow:global_step/sec: 162.36
# INFO:tensorflow:loss = 0.00131976, step = 24201 (0.613 sec)
# INFO:tensorflow:global_step/sec: 158.471
# INFO:tensorflow:loss = 9.02973e-05, step = 24301 (0.634 sec)
# INFO:tensorflow:global_step/sec: 180.836
# INFO:tensorflow:loss = 0.001884, step = 24401 (0.547 sec)
# INFO:tensorflow:global_step/sec: 169.223
# INFO:tensorflow:loss = 0.000799521, step = 24501 (0.593 sec)
# INFO:tensorflow:global_step/sec: 106.182
# INFO:tensorflow:loss = 0.00050295, step = 24601 (0.949 sec)
# INFO:tensorflow:global_step/sec: 124.798
# INFO:tensorflow:loss = 0.000779045, step = 24701 (0.794 sec)
# INFO:tensorflow:global_step/sec: 121.781
# INFO:tensorflow:loss = 0.00145219, step = 24801 (0.820 sec)
# INFO:tensorflow:global_step/sec: 130.181
# INFO:tensorflow:loss = 0.00101667, step = 24901 (0.773 sec)
# INFO:tensorflow:global_step/sec: 128.18
# INFO:tensorflow:loss = 0.000530156, step = 25001 (0.777 sec)
# INFO:tensorflow:global_step/sec: 144.751
# INFO:tensorflow:loss = 0.000576605, step = 25101 (0.689 sec)
# INFO:tensorflow:global_step/sec: 144.945
# INFO:tensorflow:loss = 0.00149352, step = 25201 (0.690 sec)
# INFO:tensorflow:global_step/sec: 132.358
# INFO:tensorflow:loss = 0.000129754, step = 25301 (0.760 sec)
# INFO:tensorflow:global_step/sec: 133.166
# INFO:tensorflow:loss = 0.000697306, step = 25401 (0.747 sec)
# INFO:tensorflow:global_step/sec: 153.927
# INFO:tensorflow:loss = 0.00110365, step = 25501 (0.650 sec)
# INFO:tensorflow:global_step/sec: 152.717
# INFO:tensorflow:loss = 0.00106835, step = 25601 (0.656 sec)
# INFO:tensorflow:global_step/sec: 172.782
# INFO:tensorflow:loss = 0.000584211, step = 25701 (0.577 sec)
# INFO:tensorflow:global_step/sec: 185.048
# INFO:tensorflow:loss = 0.000646802, step = 25801 (0.540 sec)
# INFO:tensorflow:global_step/sec: 187.987
# INFO:tensorflow:loss = 0.00162709, step = 25901 (0.532 sec)
# INFO:tensorflow:global_step/sec: 168.046
# INFO:tensorflow:loss = 3.63401e-05, step = 26001 (0.595 sec)
# INFO:tensorflow:global_step/sec: 140.67
# INFO:tensorflow:loss = 0.000833653, step = 26101 (0.710 sec)
# INFO:tensorflow:global_step/sec: 175.766
# INFO:tensorflow:loss = 0.00065895, step = 26201 (0.569 sec)
# INFO:tensorflow:global_step/sec: 195.317
# INFO:tensorflow:loss = 0.00130903, step = 26301 (0.512 sec)
# INFO:tensorflow:global_step/sec: 180.31
# INFO:tensorflow:loss = 0.00188599, step = 26401 (0.556 sec)
# INFO:tensorflow:global_step/sec: 193.224
# INFO:tensorflow:loss = 0.000732352, step = 26501 (0.517 sec)
# INFO:tensorflow:global_step/sec: 194.355
# INFO:tensorflow:loss = 0.000291816, step = 26601 (0.516 sec)
# INFO:tensorflow:global_step/sec: 173.512
# INFO:tensorflow:loss = 2.01609e-05, step = 26701 (0.575 sec)
# INFO:tensorflow:global_step/sec: 197.88
# INFO:tensorflow:loss = 0.000276299, step = 26801 (0.505 sec)
# INFO:tensorflow:global_step/sec: 192.296
# INFO:tensorflow:loss = 0.000711215, step = 26901 (0.521 sec)
# INFO:tensorflow:global_step/sec: 183.283
# INFO:tensorflow:loss = 0.000713839, step = 27001 (0.545 sec)
# INFO:tensorflow:global_step/sec: 188.914
# INFO:tensorflow:loss = 0.000496095, step = 27101 (0.533 sec)
# INFO:tensorflow:global_step/sec: 166.108
# INFO:tensorflow:loss = 0.000292127, step = 27201 (0.602 sec)
# INFO:tensorflow:global_step/sec: 139.916
# INFO:tensorflow:loss = 0.00104155, step = 27301 (0.714 sec)
# INFO:tensorflow:global_step/sec: 147.54
# INFO:tensorflow:loss = 0.000140729, step = 27401 (0.675 sec)
# INFO:tensorflow:global_step/sec: 161.266
# INFO:tensorflow:loss = 0.0018996, step = 27501 (0.620 sec)
# INFO:tensorflow:global_step/sec: 187.656
# INFO:tensorflow:loss = 0.0012483, step = 27601 (0.534 sec)
# INFO:tensorflow:global_step/sec: 171.086
# INFO:tensorflow:loss = 0.000290617, step = 27701 (0.587 sec)
# INFO:tensorflow:global_step/sec: 167.35
# INFO:tensorflow:loss = 0.000209871, step = 27801 (0.595 sec)
# INFO:tensorflow:global_step/sec: 196.532
# INFO:tensorflow:loss = 0.000403064, step = 27901 (0.509 sec)
# INFO:tensorflow:global_step/sec: 187.434
# INFO:tensorflow:loss = 0.00128387, step = 28001 (0.534 sec)
# INFO:tensorflow:global_step/sec: 149.401
# INFO:tensorflow:loss = 0.000502627, step = 28101 (0.668 sec)
# INFO:tensorflow:global_step/sec: 199.561
# INFO:tensorflow:loss = 0.00116649, step = 28201 (0.503 sec)
# INFO:tensorflow:global_step/sec: 187.414
# INFO:tensorflow:loss = 0.00100219, step = 28301 (0.532 sec)
# INFO:tensorflow:global_step/sec: 204.1
# INFO:tensorflow:loss = 0.000766078, step = 28401 (0.490 sec)
# INFO:tensorflow:global_step/sec: 171.974
# INFO:tensorflow:loss = 0.000177974, step = 28501 (0.585 sec)
# INFO:tensorflow:global_step/sec: 146.065
# INFO:tensorflow:loss = 0.000329917, step = 28601 (0.685 sec)
# INFO:tensorflow:global_step/sec: 149.415
# INFO:tensorflow:loss = 0.00123371, step = 28701 (0.666 sec)
# INFO:tensorflow:global_step/sec: 157.322
# INFO:tensorflow:loss = 0.00147715, step = 28801 (0.636 sec)
# INFO:tensorflow:global_step/sec: 187.422
# INFO:tensorflow:loss = 0.000314373, step = 28901 (0.533 sec)
# INFO:tensorflow:global_step/sec: 205.994
# INFO:tensorflow:loss = 0.00154552, step = 29001 (0.485 sec)
# INFO:tensorflow:global_step/sec: 180.651
# INFO:tensorflow:loss = 0.00129965, step = 29101 (0.553 sec)
# INFO:tensorflow:global_step/sec: 179.109
# INFO:tensorflow:loss = 0.00129585, step = 29201 (0.559 sec)
# INFO:tensorflow:global_step/sec: 183.385
# INFO:tensorflow:loss = 0.00121168, step = 29301 (0.545 sec)
# INFO:tensorflow:global_step/sec: 166.818
# INFO:tensorflow:loss = 0.000909253, step = 29401 (0.599 sec)
# INFO:tensorflow:global_step/sec: 180.938
# INFO:tensorflow:loss = 0.000941037, step = 29501 (0.553 sec)
# INFO:tensorflow:global_step/sec: 191.58
# INFO:tensorflow:loss = 0.000364455, step = 29601 (0.524 sec)
# INFO:tensorflow:global_step/sec: 152.194
# INFO:tensorflow:loss = 0.00035693, step = 29701 (0.658 sec)
# INFO:tensorflow:global_step/sec: 186.335
# INFO:tensorflow:loss = 0.000925956, step = 29801 (0.535 sec)
# INFO:tensorflow:global_step/sec: 183.265
# INFO:tensorflow:loss = 0.000835431, step = 29901 (0.545 sec)
# INFO:tensorflow:global_step/sec: 184.652
# INFO:tensorflow:loss = 5.97498e-05, step = 30001 (0.542 sec)
# INFO:tensorflow:global_step/sec: 187.644
# INFO:tensorflow:loss = 0.000462301, step = 30101 (0.533 sec)
# INFO:tensorflow:global_step/sec: 186.484
# INFO:tensorflow:loss = 0.000337605, step = 30201 (0.538 sec)
# INFO:tensorflow:global_step/sec: 175.64
# INFO:tensorflow:loss = 0.001265, step = 30301 (0.568 sec)
# INFO:tensorflow:global_step/sec: 191.157
# INFO:tensorflow:loss = 0.00113585, step = 30401 (0.523 sec)
# INFO:tensorflow:global_step/sec: 192.081
# INFO:tensorflow:loss = 0.00104992, step = 30501 (0.520 sec)
# INFO:tensorflow:global_step/sec: 191.843
# INFO:tensorflow:loss = 0.00111257, step = 30601 (0.521 sec)
# INFO:tensorflow:global_step/sec: 190.181
# INFO:tensorflow:loss = 0.000718876, step = 30701 (0.527 sec)
# INFO:tensorflow:global_step/sec: 183.601
# INFO:tensorflow:loss = 0.00107485, step = 30801 (0.544 sec)
# INFO:tensorflow:global_step/sec: 179.764
# INFO:tensorflow:loss = 0.00114239, step = 30901 (0.558 sec)
# INFO:tensorflow:global_step/sec: 145.358
# INFO:tensorflow:loss = 0.00140516, step = 31001 (0.686 sec)
# INFO:tensorflow:global_step/sec: 172.564
# INFO:tensorflow:loss = 0.000977299, step = 31101 (0.581 sec)
# INFO:tensorflow:global_step/sec: 172.331
# INFO:tensorflow:loss = 0.000518591, step = 31201 (0.579 sec)
# INFO:tensorflow:global_step/sec: 187.202
# INFO:tensorflow:loss = 0.000444629, step = 31301 (0.535 sec)
# INFO:tensorflow:global_step/sec: 177.648
# INFO:tensorflow:loss = 0.000820931, step = 31401 (0.567 sec)
# INFO:tensorflow:global_step/sec: 142.199
# INFO:tensorflow:loss = 0.000336384, step = 31501 (0.700 sec)
# INFO:tensorflow:global_step/sec: 180.428
# INFO:tensorflow:loss = 0.00011521, step = 31601 (0.553 sec)
# INFO:tensorflow:global_step/sec: 193.076
# INFO:tensorflow:loss = 0.000637093, step = 31701 (0.518 sec)
# INFO:tensorflow:global_step/sec: 183.606
# INFO:tensorflow:loss = 0.000241198, step = 31801 (0.545 sec)
# INFO:tensorflow:global_step/sec: 163.62
# INFO:tensorflow:loss = 0.000807697, step = 31901 (0.611 sec)
# INFO:tensorflow:global_step/sec: 180.843
# INFO:tensorflow:loss = 0.000330729, step = 32001 (0.554 sec)
# INFO:tensorflow:global_step/sec: 134.369
# INFO:tensorflow:loss = 0.000487922, step = 32101 (0.747 sec)
# INFO:tensorflow:global_step/sec: 156.948
# INFO:tensorflow:loss = 0.00114426, step = 32201 (0.634 sec)
# INFO:tensorflow:global_step/sec: 177.993
# INFO:tensorflow:loss = 0.00048702, step = 32301 (0.565 sec)
# INFO:tensorflow:global_step/sec: 138.59
# INFO:tensorflow:loss = 0.000155042, step = 32401 (0.722 sec)
# INFO:tensorflow:global_step/sec: 147.42
# INFO:tensorflow:loss = 0.000478657, step = 32501 (0.674 sec)
# INFO:tensorflow:global_step/sec: 194.574
# INFO:tensorflow:loss = 5.67741e-05, step = 32601 (0.514 sec)
# INFO:tensorflow:global_step/sec: 184.484
# INFO:tensorflow:loss = 0.000897279, step = 32701 (0.542 sec)
# INFO:tensorflow:global_step/sec: 179.168
# INFO:tensorflow:loss = 0.000881463, step = 32801 (0.559 sec)
# INFO:tensorflow:global_step/sec: 167.476
# INFO:tensorflow:loss = 0.000444245, step = 32901 (0.596 sec)
# INFO:tensorflow:global_step/sec: 159.643
# INFO:tensorflow:loss = 0.000331114, step = 33001 (0.627 sec)
# INFO:tensorflow:global_step/sec: 175.813
# INFO:tensorflow:loss = 0.00187838, step = 33101 (0.569 sec)
# INFO:tensorflow:global_step/sec: 185.417
# INFO:tensorflow:loss = 0.00118372, step = 33201 (0.540 sec)
# INFO:tensorflow:global_step/sec: 154.199
# INFO:tensorflow:loss = 0.000289322, step = 33301 (0.650 sec)
# INFO:tensorflow:global_step/sec: 165.116
# INFO:tensorflow:loss = 0.0012003, step = 33401 (0.602 sec)
# INFO:tensorflow:global_step/sec: 143.298
# INFO:tensorflow:loss = 0.000296112, step = 33501 (0.702 sec)
# INFO:tensorflow:global_step/sec: 158.293
# INFO:tensorflow:loss = 0.000894414, step = 33601 (0.630 sec)
# INFO:tensorflow:global_step/sec: 161.916
# INFO:tensorflow:loss = 0.000768437, step = 33701 (0.615 sec)
# INFO:tensorflow:global_step/sec: 158.178
# INFO:tensorflow:loss = 0.000554916, step = 33801 (0.632 sec)
# INFO:tensorflow:global_step/sec: 157.251
# INFO:tensorflow:loss = 0.00131193, step = 33901 (0.642 sec)
# INFO:tensorflow:global_step/sec: 161.602
# INFO:tensorflow:loss = 0.000844884, step = 34001 (0.614 sec)
# INFO:tensorflow:global_step/sec: 176.391
# INFO:tensorflow:loss = 0.000634743, step = 34101 (0.571 sec)
# INFO:tensorflow:global_step/sec: 169.424
# INFO:tensorflow:loss = 0.00116871, step = 34201 (0.586 sec)
# INFO:tensorflow:global_step/sec: 175.023
# INFO:tensorflow:loss = 7.8121e-05, step = 34301 (0.572 sec)
# INFO:tensorflow:global_step/sec: 176.387
# INFO:tensorflow:loss = 0.000426132, step = 34401 (0.570 sec)
# INFO:tensorflow:global_step/sec: 166.738
# INFO:tensorflow:loss = 0.000392799, step = 34501 (0.596 sec)
# INFO:tensorflow:global_step/sec: 159.122
# INFO:tensorflow:loss = 0.000569354, step = 34601 (0.630 sec)
# INFO:tensorflow:global_step/sec: 166.805
# INFO:tensorflow:loss = 0.00170119, step = 34701 (0.600 sec)
# INFO:tensorflow:global_step/sec: 150.796
# INFO:tensorflow:loss = 0.000542411, step = 34801 (0.661 sec)
# INFO:tensorflow:global_step/sec: 145.594
# INFO:tensorflow:loss = 0.000603943, step = 34901 (0.693 sec)
# INFO:tensorflow:global_step/sec: 158.57
# INFO:tensorflow:loss = 0.000281414, step = 35001 (0.625 sec)
# INFO:tensorflow:global_step/sec: 178.006
# INFO:tensorflow:loss = 0.00115438, step = 35101 (0.561 sec)
# INFO:tensorflow:global_step/sec: 173.126
# INFO:tensorflow:loss = 0.000342417, step = 35201 (0.579 sec)
# INFO:tensorflow:global_step/sec: 177.218
# INFO:tensorflow:loss = 0.000128509, step = 35301 (0.563 sec)
# INFO:tensorflow:global_step/sec: 169.709
# INFO:tensorflow:loss = 0.000782394, step = 35401 (0.592 sec)
# INFO:tensorflow:global_step/sec: 157.996
# INFO:tensorflow:loss = 0.000319408, step = 35501 (0.633 sec)
# INFO:tensorflow:global_step/sec: 142.803
# INFO:tensorflow:loss = 0.00016617, step = 35601 (0.700 sec)
# INFO:tensorflow:global_step/sec: 170.938
# INFO:tensorflow:loss = 0.000693239, step = 35701 (0.584 sec)
# INFO:tensorflow:global_step/sec: 184.579
# INFO:tensorflow:loss = 0.000461559, step = 35801 (0.540 sec)
# INFO:tensorflow:global_step/sec: 159.311
# INFO:tensorflow:loss = 0.000595952, step = 35901 (0.630 sec)
# INFO:tensorflow:global_step/sec: 166.712
# INFO:tensorflow:loss = 0.000324711, step = 36001 (0.598 sec)
# INFO:tensorflow:global_step/sec: 146.236
# INFO:tensorflow:loss = 0.00145555, step = 36101 (0.688 sec)
# INFO:tensorflow:global_step/sec: 156.275
# INFO:tensorflow:loss = 0.00078514, step = 36201 (0.636 sec)
# INFO:tensorflow:global_step/sec: 143.995
# INFO:tensorflow:loss = 0.000336973, step = 36301 (0.697 sec)
# INFO:tensorflow:global_step/sec: 145.56
# INFO:tensorflow:loss = 0.000991783, step = 36401 (0.688 sec)
# INFO:tensorflow:global_step/sec: 160.114
# INFO:tensorflow:loss = 0.000264428, step = 36501 (0.623 sec)
# INFO:tensorflow:global_step/sec: 149.092
# INFO:tensorflow:loss = 0.000332402, step = 36601 (0.671 sec)
# INFO:tensorflow:global_step/sec: 174.836
# INFO:tensorflow:loss = 0.000367739, step = 36701 (0.571 sec)
# INFO:tensorflow:global_step/sec: 164.883
# INFO:tensorflow:loss = 0.000909691, step = 36801 (0.603 sec)
# INFO:tensorflow:global_step/sec: 157.765
# INFO:tensorflow:loss = 0.000658553, step = 36901 (0.640 sec)
# INFO:tensorflow:global_step/sec: 148.783
# INFO:tensorflow:loss = 0.000706538, step = 37001 (0.666 sec)
# INFO:tensorflow:global_step/sec: 147.638
# INFO:tensorflow:loss = 0.000168055, step = 37101 (0.677 sec)
# INFO:tensorflow:global_step/sec: 160.579
# INFO:tensorflow:loss = 0.00017816, step = 37201 (0.625 sec)
# INFO:tensorflow:global_step/sec: 148.428
# INFO:tensorflow:loss = 0.000575811, step = 37301 (0.672 sec)
# INFO:tensorflow:global_step/sec: 178.016
# INFO:tensorflow:loss = 0.000286379, step = 37401 (0.562 sec)
# INFO:tensorflow:global_step/sec: 185.657
# INFO:tensorflow:loss = 0.000244035, step = 37501 (0.541 sec)
# INFO:tensorflow:global_step/sec: 194.978
# INFO:tensorflow:loss = 0.000319354, step = 37601 (0.510 sec)
# INFO:tensorflow:global_step/sec: 190.1
# INFO:tensorflow:loss = 8.79634e-05, step = 37701 (0.526 sec)
# INFO:tensorflow:global_step/sec: 187.862
# INFO:tensorflow:loss = 0.000483344, step = 37801 (0.532 sec)
# INFO:tensorflow:global_step/sec: 188.471
# INFO:tensorflow:loss = 0.00125285, step = 37901 (0.531 sec)
# INFO:tensorflow:global_step/sec: 162.393
# INFO:tensorflow:loss = 0.000345127, step = 38001 (0.616 sec)
# INFO:tensorflow:global_step/sec: 171.691
# INFO:tensorflow:loss = 0.000797029, step = 38101 (0.582 sec)
# INFO:tensorflow:global_step/sec: 177.665
# INFO:tensorflow:loss = 0.000688518, step = 38201 (0.563 sec)
# INFO:tensorflow:global_step/sec: 190.278
# INFO:tensorflow:loss = 7.44853e-05, step = 38301 (0.525 sec)
# INFO:tensorflow:global_step/sec: 182.475
# INFO:tensorflow:loss = 0.000127539, step = 38401 (0.548 sec)
# INFO:tensorflow:global_step/sec: 184.904
# INFO:tensorflow:loss = 0.000383127, step = 38501 (0.541 sec)
# INFO:tensorflow:global_step/sec: 186.907
# INFO:tensorflow:loss = 0.000798221, step = 38601 (0.535 sec)
# INFO:tensorflow:global_step/sec: 183.218
# INFO:tensorflow:loss = 0.000382044, step = 38701 (0.546 sec)
# INFO:tensorflow:global_step/sec: 166.832
# INFO:tensorflow:loss = 0.000175323, step = 38801 (0.599 sec)
# INFO:tensorflow:global_step/sec: 185.624
# INFO:tensorflow:loss = 0.00137722, step = 38901 (0.539 sec)
# INFO:tensorflow:global_step/sec: 185.228
# INFO:tensorflow:loss = 0.000287098, step = 39001 (0.540 sec)
# INFO:tensorflow:global_step/sec: 186.004
# INFO:tensorflow:loss = 0.000775865, step = 39101 (0.538 sec)
# INFO:tensorflow:global_step/sec: 186.761
# INFO:tensorflow:loss = 0.000338872, step = 39201 (0.536 sec)
# INFO:tensorflow:global_step/sec: 189.212
# INFO:tensorflow:loss = 0.000381685, step = 39301 (0.528 sec)
# INFO:tensorflow:global_step/sec: 186.22
# INFO:tensorflow:loss = 0.000412356, step = 39401 (0.537 sec)
# INFO:tensorflow:global_step/sec: 188.1
# INFO:tensorflow:loss = 0.000119158, step = 39501 (0.531 sec)
# INFO:tensorflow:global_step/sec: 189.595
# INFO:tensorflow:loss = 0.000545798, step = 39601 (0.528 sec)
# INFO:tensorflow:global_step/sec: 185.112
# INFO:tensorflow:loss = 0.000145572, step = 39701 (0.540 sec)
# INFO:tensorflow:global_step/sec: 183.628
# INFO:tensorflow:loss = 0.000797458, step = 39801 (0.545 sec)
# INFO:tensorflow:global_step/sec: 178.376
# INFO:tensorflow:loss = 0.00103634, step = 39901 (0.565 sec)
# INFO:tensorflow:Saving checkpoints for 40000 into /var/folders/__/2zbjvd9s6w54xb911mgsqj6w0000gn/T/tmps9a3c8vc/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.000354947.
# DNNClassifier(params={'head': <tensorflow.contrib.learn.python.learn.estimators.head._MultiClassHead object at 0x125c26d30>, 'hidden_units': [300, 100], 'feature_columns': (_RealValuedColumn(column_name='', dimension=784, default_value=None, dtype=tf.float32, normalizer=None),), 'optimizer': None, 'activation_fn': <function relu at 0x1167bdae8>, 'dropout': None, 'gradient_clip_norm': None, 'embedding_lr_multipliers': None, 'input_layer_min_slice_size': None})

# %%
from sklearn.metrics import accuracy_score
y_pred = list(dnn_clf.predict(X_test))
accuracy_score(y_test, y_pred)
# Out:
# WARNING:tensorflow:From //anaconda/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:347: calling DNNClassifier.predict (from tensorflow.contrib.learn.python.learn.estimators.dnn) with outputs=None is deprecated and will be removed after 2017-03-01.
# Instructions for updating:
# Please switch to predict_classes, or set `outputs` argument.
# WARNING:tensorflow:From //anaconda/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/dnn.py:433: calling BaseEstimator.predict (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# INFO:tensorflow:Restoring parameters from /var/folders/__/2zbjvd9s6w54xb911mgsqj6w0000gn/T/tmps9a3c8vc/model.ckpt-40000
# 0.9829

# %% [markdown]
# ## Training a DNN Using Plain TensorFlow
#
# * The first step is the construction phase, building the TensorFlow graph. The second step is the execution phase, where we actually run the graph to train the model.
#
# ### Construction Phase

# %%
n_inputs = 28*28
n_hidden1 = 300
n_hidden2 = 100
n_outputs = 10

# %%
reset_graph()

X = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
y = tf.placeholder(tf.int64, shape=(None), name="y")

# create the two hidden layers and the output layer.

def neuron_layer(X, n_neurons, name, activation=None):
    with tf.name_scope(name):
        n_inputs = int(X.get_shape()[1])
        stddev = 2 / np.sqrt(n_inputs)
        init = tf.truncated_normal((n_inputs, n_neurons), stddev=stddev)
        W = tf.Variable(init, name="weight")
        b = tf.Variable(tf.zeros([n_neurons]), name="biases")
        z = tf.matmul(X, W) + b
        if activation == "relu":
            return tf.nn.relu(z)
        else:
            return z

# %% [markdown]
# 1. First we create a name scope using the name of the layer: it will contain all the computaion nodes for this neuron layer.
#
# 2. Next, we get the number of inputs by looking up the input matrix's shape and getting the size of the second dimension(the first dimension is for instances)
#
# 3. The next three lines create a W variable that will hold the weights matrix. It will be a 2D tensor containing all the connection weights between each input and each neuron. its shape will be (n_inputs, n_neurons). It will be initialized randomly, using a truncated normal(Gaussian) disstribution with a standard deviation of 2/sqrt(n_inputs). Using this specific standard deviation helps the algorithm converge much faster.
#
# 4. The next line creates a b variable for biases, initialized to 0 (no symmetry issue in this case), with one bias parameter per neuron.

# %%
# create the deep neural network.

with tf.name_scope("dnn"):
    hidden1 = neuron_layer(X, n_hidden1, "hidden1", activation="relu")
    hidden2 = neuron_layer(hidden1, n_hidden2, "hidden2", activation="relu")
    logits = neuron_layer(hidden2, n_outputs, "outputs")

# %%
with tf.name_scope("loss"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy, name="loss")
    
# The sparse_softmax_cross_entropy_with_logits() function is equivalent to applying the softmax
#activation function and then computing the cross entropy.

# %%
# Define a GradientDescentOptimizer
learning_rate = 0.01

with tf.name_scope("train"):
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    training_op = optimizer.minimize(loss)

# %%
with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

# %%
init = tf.global_variables_initializer()
saver = tf.train.Saver()

# %% [markdown]
# ### Execution Phase

# %%
n_epochs = 40
batch_size = 50

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        for iteration in range(mnist.train.num_examples // batch_size):
            X_batch, y_batch = mnist.train.next_batch(batch_size)
            sess.run(training_op, feed_dict={X: X_batch, y:y_batch})
        acc_train = accuracy.eval(feed_dict={X: X_batch, y:y_batch})
        acc_test = accuracy.eval(feed_dict={X: mnist.test.images, y: mnist.test.labels})
        print(epoch, "Train accuracy:", acc_train, "Test accuracy:", acc_test)
    save_path = saver.save(sess, "./my_model_final.ckpt")
# Out:
# 0 Train accuracy: 0.92 Test accuracy: 0.9111
# 1 Train accuracy: 0.94 Test accuracy: 0.9301
# 2 Train accuracy: 0.92 Test accuracy: 0.9388
# 3 Train accuracy: 0.98 Test accuracy: 0.9453
# 4 Train accuracy: 0.92 Test accuracy: 0.9499
# 5 Train accuracy: 0.92 Test accuracy: 0.9547
# 6 Train accuracy: 0.96 Test accuracy: 0.9578
# 7 Train accuracy: 1.0 Test accuracy: 0.9602
# 8 Train accuracy: 0.94 Test accuracy: 0.9615
# 9 Train accuracy: 1.0 Test accuracy: 0.9637
# 10 Train accuracy: 0.98 Test accuracy: 0.9658
# 11 Train accuracy: 0.98 Test accuracy: 0.9663
# 12 Train accuracy: 1.0 Test accuracy: 0.967
# 13 Train accuracy: 0.96 Test accuracy: 0.9692
# 14 Train accuracy: 0.96 Test accuracy: 0.9698
# 15 Train accuracy: 0.98 Test accuracy: 0.9709
# 16 Train accuracy: 0.98 Test accuracy: 0.9711
# 17 Train accuracy: 0.98 Test accuracy: 0.9719
# 18 Train accuracy: 1.0 Test accuracy: 0.9727
# 19 Train accuracy: 0.96 Test accuracy: 0.9732
# 20 Train accuracy: 0.96 Test accuracy: 0.9729
# 21 Train accuracy: 1.0 Test accuracy: 0.9735
# 22 Train accuracy: 1.0 Test accuracy: 0.9741
# 23 Train accuracy: 0.98 Test accuracy: 0.9751
# 24 Train accuracy: 1.0 Test accuracy: 0.9751
# 25 Train accuracy: 1.0 Test accuracy: 0.975
# 26 Train accuracy: 0.98 Test accuracy: 0.9753
# 27 Train accuracy: 0.98 Test accuracy: 0.9755
# 28 Train accuracy: 0.98 Test accuracy: 0.9759
# 29 Train accuracy: 1.0 Test accuracy: 0.9766
# 30 Train accuracy: 1.0 Test accuracy: 0.9763
# 31 Train accuracy: 1.0 Test accuracy: 0.9756
# 32 Train accuracy: 1.0 Test accuracy: 0.977
# 33 Train accuracy: 1.0 Test accuracy: 0.9763
# 34 Train accuracy: 0.98 Test accuracy: 0.9767
# 35 Train accuracy: 1.0 Test accuracy: 0.9767
# 36 Train accuracy: 1.0 Test accuracy: 0.9768
# 37 Train accuracy: 1.0 Test accuracy: 0.9775
# 38 Train accuracy: 1.0 Test accuracy: 0.9776
# 39 Train accuracy: 1.0 Test accuracy: 0.978

# %% [markdown]
# ### Using the Neural Network
#
# * we can use the trained neural network to make predictions

# %%
with tf.Session() as sess:
    saver.restore(sess, "./my_model_final.ckpt")
    X_new_scaled = mnist.test.images[:20]
    Z = logits.eval(feed_dict={X: X_new_scaled})
    y_pred = np.argmax(Z, axis=1)

print("PRedicted classed:", y_pred)
print("Actual classes: ", mnist.test.labels[:20])
# Out:
# INFO:tensorflow:Restoring parameters from ./my_model_final.ckpt
# PRedicted classed: [7 2 1 0 4 1 4 9 5 9 0 6 9 0 1 5 9 7 3 4]
# Actual classes:  [7 2 1 0 4 1 4 9 5 9 0 6 9 0 1 5 9 7 3 4]

# %% [markdown]
# ## Fine-Tuning Neural Network Hyperparameters
#
# * The flexibility of neural networks is also one of their main drawbacks: there are many hyperparameters to tweak.
#
# ### Number of Hidden Layers
#
# * For many problems, we can just begin with a single hidden layer and we will get reasonable results.
#
# * Deep networks have a much higher parameter efficiency than shallow ones: they can model complex functions using exponentially fewer neurons than shallow nets, making them much faster to train.
#
# * In summary, for many problems we can start with just one or two hidden layers and it will work just fine.
#
# * For more complex problems, we can gradually ramp up the number of hidden layers, until we start overfitting the training set.
#
# ### Number of Neurons per Hidden Layers
#
# * The number of neurons in the input and output layers is determined by the type of input and output our task requires.
#
# * As for the hidden layers, a common practice is to size them to form a funnel, with fewer and fewer neurons at each layer---the rationable being that many low-level features can coalesce into far fewer high-level features.
#
# * A simpler approach is to pick a model with more layers and neurons than we actually need, then use early stopping to prevent it from overfitting.
#
# ### Activation Functions
#
# * In most cases we can use the ReLU activation fucntion in the hidden layers. It is a bit faster to compute than other activation functions, and Gradient Descent does not get stuck as much on plateaus.
#
# * For the output layer, the softmax activation function is generally a good choice for classification tasks.
